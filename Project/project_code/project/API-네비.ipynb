# %%
import simplejson,requests
import sys
 
url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "43f61baacdccdb0be07a4deac34cf464"
query = "서울랜드도깨비바람"
 
r = requests.get( url, params = {'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } )
js = simplejson.JSONEncoder().encode(r.json())
r.json()
# Out:
# {'documents': [{'address_name': '경기 과천시 막계동 77',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소 > 테마파크 > 테마파크시설',
#    'distance': '',
#    'id': '17579753',
#    'phone': '',
#    'place_name': '서울랜드 도깨비바람',
#    'place_url': 'http://place.map.kakao.com/17579753',
#    'road_address_name': '',
#    'x': '127.0184853355',
#    'y': '37.4345335773292'}],
#  'meta': {'is_end': True,
#   'pageable_count': 1,
#   'same_name': {'keyword': '서울랜드도깨비바람', 'region': [], 'selected_region': ''},
#   'total_count': 1}}

# %%
url = "https://dapi.kakao.com/v2/local/search/keyword.json?"
apikey = "43f61baacdccdb0be07a4deac34cf464"
query = "서울랜드회전목마"
 
r = requests.get( url, params = {'query':query}, headers={'Authorization' : 'KakaoAK ' + apikey } )
js = simplejson.JSONEncoder().encode(r.json())
r.json()
# Out:
# {'documents': [{'address_name': '경기 과천시 막계동 924',
#    'category_group_code': '',
#    'category_group_name': '',
#    'category_name': '여행 > 관광,명소 > 테마파크 > 테마파크시설',
#    'distance': '',
#    'id': '17583361',
#    'phone': '',
#    'place_name': '서울랜드 빅회전목마',
#    'place_url': 'http://place.map.kakao.com/17583361',
#    'road_address_name': '',
#    'x': '127.020035120133',
#    'y': '37.4328358101958'}],
#  'meta': {'is_end': True,
#   'pageable_count': 1,
#   'same_name': {'keyword': '회전목마',
#    'region': [],
#    'selected_region': '경기 과천시 서울랜드'},
#   'total_count': 1}}

# %%
mathod='GET'
url = "https://apis-navi.kakaomobility.com/v1/future/directions"
apikey = "43f61baacdccdb0be07a4deac34cf464"
origin = "127.020035120133,37.4328358101958"
destination = "127.0184853355,37.4345335773292"
car_type ='8'
departure_time = '202112120000'
 
r = requests.get(url=url, params = {'origin':origin,'destination':destination, 'departure_time':departure_time,'car_type':car_type}, headers={'Authorization' : 'KakaoAK ' + apikey } )
js = simplejson.JSONEncoder().encode(r.json())
r.json()
# Out:
# {'trans_id': '4f5abbe0678f4a3e8d63e0408823ebbe',
#  'routes': [{'result_code': 0,
#    'result_msg': '길찾기 성공',
#    'summary': {'origin': {'name': '',
#      'x': 127.020026857429,
#      'y': 37.432830934445064},
#     'destination': {'name': '',
#      'x': 127.0184792432613,
#      'y': 37.43453011547484},
#     'waypoints': [],
#     'priority': 'RECOMMEND',
#     'bound': {'min_x': 127.01735235846505,
#      'min_y': 37.4325654435606,
#      'max_x': 127.02405685629732,
#      'max_y': 37.43661270477617},
#     'fare': {'taxi': 3800, 'toll': 0},
#     'distance': 1297,
#     'duration': 196},
#    'sections': [{'distance': 1297,
#      'duration': 196,
#      'bound': {'min_x': 127.01730641949241,
#       'min_y': 37.43258917191291,
#       'max_x': 127.02408516770073,
#       'max_y': 37.43656188787496},
#      'roads': [{'name': '광명로',
#        'distance': 538,
#        'duration': 70,
#        'traffic_speed': 28.0,
#        'traffic_state': 0,
# ...
