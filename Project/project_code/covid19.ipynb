# %%
from xml.etree.ElementTree import parse

# %%
tree = parse('covid19.xml')
root = tree.getroot()

root
# Out:
# <Element 'response' at 0x7ff6d35908f0>

# %%
root.tag
# Out:
# 'response'

# %%
for data in root.findall('body/items/item'):
    date = data.find('stateDt').text
    defs = data.find('decideCnt').text  # 확진자수
    print(date,defs)
# Out:
# 20210630 156960
# 20210629 156166
# 20210628 155571
# 20210627 155070
# 20210626 154456
# 20210625 153788
# 20210624 153154
# 20210623 152544
# 20210622 151899
# 20210621 151505
# 20210620 151148
# 20210619 150719
# 20210618 150237
# 20210617 149730
# 20210616 149190
# 20210615 148645
# 20210614 148272
# 20210613 147873
# 20210612 147421
# 20210611 146856
# 20210610 146300
# 20210609 145690
# 20210608 145088
# 20210607 144634
# 20210606 144149
# 20210605 143593
# 20210604 142849
# 20210603 142154
# 20210602 141473
# 20210601 140796
# 20210531 140337
# 20210530 139907
# 20210529 139427
# 20210528 138894
# 20210527 138307
# 20210526 137678
# 20210525 136973
# 20210524 136457
# 20210523 135927
# 20210522 135342
# 20210521 134676
# 20210520 134115
# 20210519 133469
# 20210518 132815
# 20210517 132287
# 20210516 131668
# 20210515 131058
# 20210514 130377
# 20210513 129630
# 20210512 128915
# 20210511 128281
# 20210510 127771
# 20210509 127308
# 20210508 126744
# 20210507 126043
# ...
