# %% [markdown]
# ### 선 그래프
# + 시간에 따른 데이터의 변화를 시각화하는 유용하게 사용
#     - 지난 10년간 경유 가격의 평균값
#     - 지난 두달간 몸무게 변화
# + 시계열 데이터를 시각화 하는 주로 사용
# + plot(x축값, y축값, type='l')
# + lines(x축값, y축값)

# %%
# 학생 10명의 키 데이터 시각화
load('rdata/height.rdata')
plot(height, type='l', col='red')
# Out:
# plot without title

# %%
# 항공사 승객 데이터
plot(AirPassengers, type='l', col='red')
# Out:
# plot without title

# %%
# 나일강 홍수 데이터
plot(Nile, type='l', col='red')
# Out:
# plot without title
